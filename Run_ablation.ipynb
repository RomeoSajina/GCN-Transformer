# %% [markdown]
# # Ablation study

# %%
# Baseline: (Scene-GCN & Spatio-Temporal Transformer Decoder)
# !python train_ablation.py --dataset 3dpw_ablation_1 --ablation_exclude augmentation vel_loss scene_loss temporal_gcn
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_1/
# Config: Namespace(J=13, N=2, ablation_exclude=['augmentation', 'vel_loss', 'scene_loss', 'temporal_gcn'], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw_ablation_1', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_1/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 24800
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 3284298 3284298
# EPOCH 1 | loss train: 0.470, loss valid: 0.202 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 53.36 60.86 83.16 94.04 114.57  - 81.20
# EPOCH 2 | loss train: 0.176, loss valid: 0.186 | lr: 0.00100
# ...

# %%
# !python test.py --dataset 3dpw_ablation --ckp ./logs/3dpw_ablation_1/best_epoch.pt  --ablation_exclude temporal_gcn
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/
# Config: Namespace(J=13, N=2, ablation_exclude=['temporal_gcn'], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw_ablation_1/best_epoch.pt', dataset='3dpw_ablation', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 3284298 3284298
# Loading model from: ./logs/3dpw_ablation_1/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 15.39 28.53 55.90 68.72 93.92  - 52.49
# Test MPJPE s 240ms 500ms 640ms 900ms]: 31.81 45.19 77.03 93.68 127.60  - 75.06

# %% [markdown]
# ---

# %%
# Adding: Temporal GCN
# !python train_ablation.py --dataset 3dpw_ablation_2 --ablation_exclude augmentation vel_loss scene_loss
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_2/
# Config: Namespace(J=13, N=2, ablation_exclude=['augmentation', 'vel_loss', 'scene_loss'], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw_ablation_2', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_2/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 24800
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.433, loss valid: 0.198 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 52.11 59.32 82.31 93.49 112.13  - 79.87
# EPOCH 2 | loss train: 0.174, loss valid: 0.183 | lr: 0.00100
# ...

# %%
# !python test.py --dataset 3dpw_ablation --ckp ./logs/3dpw_ablation_2/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw_ablation_2/best_epoch.pt', dataset='3dpw_ablation', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpw_ablation_2/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 12.69 28.96 58.96 69.74 89.56  - 51.98
# Test MPJPE s 240ms 500ms 640ms 900ms]: 23.99 41.47 79.33 96.38 127.61  - 73.76

# %% [markdown]
# ---

# %%
# Adding: scene-loss
# !python train_ablation.py --dataset 3dpw_ablation_3 --ablation_exclude augmentation vel_loss
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_3/
# Config: Namespace(J=13, N=2, ablation_exclude=['augmentation', 'vel_loss'], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw_ablation_3', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_3/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 24800
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.602, loss valid: 0.200 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 52.81 60.03 82.39 94.41 113.52  - 80.63
# EPOCH 2 | loss train: 0.332, loss valid: 0.182 | lr: 0.00100
# ...

# %%
# !python test.py --dataset 3dpw_ablation --ckp ./logs/3dpw_ablation_3/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw_ablation_3/best_epoch.pt', dataset='3dpw_ablation', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpw_ablation_3/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 11.08 28.80 57.52 67.55 87.95  - 50.58
# Test MPJPE s 240ms 500ms 640ms 900ms]: 18.09 37.54 76.08 92.69 123.51  - 69.58

# %% [markdown]
# ---

# %%
# Adding: velocity-loss
# !python train_ablation.py --dataset 3dpw_ablation_4 --ablation_exclude augmentation
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_4/
# Config: Namespace(J=13, N=2, ablation_exclude=['augmentation'], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw_ablation_4', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_4/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 24800
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.824, loss valid: 0.202 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 54.41 61.25 83.60 94.68 113.24  - 81.44
# EPOCH 2 | loss train: 0.386, loss valid: 0.185 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 44.36 51.88 75.07 87.75 113.76  - 74.56
# ...

# %%
# !python test.py --dataset 3dpw_ablation --ckp ./logs/3dpw_ablation_4/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw_ablation_4/best_epoch.pt', dataset='3dpw_ablation', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpw_ablation_4/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 12.21 28.30 56.12 66.42 87.67  - 50.14
# Test MPJPE s 240ms 500ms 640ms 900ms]: 22.79 39.90 75.28 91.15 121.77  - 70.18

# %% [markdown]
# ----

# %%
# Adding: augmentation
# !python train_ablation.py --dataset 3dpw_ablation_5
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_5/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw_ablation_5', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation_5/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.702, loss valid: 0.161 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 24.66 39.93 70.57 84.95 101.48  - 64.32
# EPOCH 2 | loss train: 0.437, loss valid: 0.138 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 18.68 33.99 61.25 72.69 89.25  - 55.17
# ...

# %%
# !python test.py --dataset 3dpw_ablation --ckp ./logs/3dpw_ablation_5/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw_ablation_5/best_epoch.pt', dataset='3dpw_ablation', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw_ablation/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw* dataset for training...
# Loaded 3DPWAmass, number of examples: 74400
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpw_ablation_5/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 7.56 19.66 44.72 56.08 75.12  - 40.63
# Test MPJPE s 240ms 500ms 640ms 900ms]: 11.68 24.35 53.50 68.34 96.97  - 50.97
