# %% [markdown]
# # SoMoF Benchmark

# %%
# !python train.py --dataset 3dpw
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpw', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpw/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw+amass* dataset for training...
# Loaded 3DPWAmass, number of examples: 991489
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# Loading *somoftest* dataset for testing...
# Loaded SoMoF_3DPW 'test', number of examples: 85
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.214, loss valid: 0.102 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 14.63 29.16 58.26 73.60 105.48  - 56.23
# EPOCH 2 | loss train: 0.151, loss valid: 0.097 | lr: 0.00100
# ...

# %%
# !python test.py --dataset 3dpw --ckp ./logs/3dpw/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/logs/3dpw/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpw/best_epoch.pt', dataset='3dpw', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/logs/3dpw/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw+amass* dataset for training...
# Loaded 3DPWAmass, number of examples: 991489
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# Loading *somoftest* dataset for testing...
# Loaded SoMoF_3DPW 'test', number of examples: 85
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpw/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 10.14 22.54 48.81 63.67 94.94  - 48.02
# Test MPJPE s 240ms 500ms 640ms 900ms]: 17.11 31.48 62.62 80.14 118.14  - 61.90

# %% [markdown]
# <br/>
#
# ---
#
# <br/>

# %% [markdown]
# # SoMoF Benchmark (*)
# Including the validation set in the training set

# %%
# !python train.py --dataset 3dpwfull
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpwfull/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='3dpwfull', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/3dpwfull/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpwfull+amass* dataset for training...
# Loaded 3DPWAmass, number of examples: 1049131
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# Loading *somoftest* dataset for testing...
# Loaded SoMoF_3DPW 'test', number of examples: 85
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.223, loss valid: 0.104 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 17.68 32.55 59.54 75.29 104.66  - 57.94
# EPOCH 2 | loss train: 0.158, loss valid: 0.099 | lr: 0.00100
# ...

# %%
# !python test.py --dataset 3dpw --ckp ./logs/3dpwfull/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/logs/3dpw/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/3dpwfull/best_epoch.pt', dataset='3dpw', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/logs/3dpw/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loading *3dpw+amass* dataset for training...
# Loaded 3DPWAmass, number of examples: 991489
# Loading *somofvalid* dataset for validation...
# Loaded SoMoF_3DPW 'valid', number of examples: 36
# Loading *somoftest* dataset for testing...
# Loaded SoMoF_3DPW 'test', number of examples: 85
# #Param: 5882454 5882454
# Loading model from: ./logs/3dpwfull/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 9.82 21.80 46.61 60.88 91.95  - 46.21
# Test MPJPE s 240ms 500ms 640ms 900ms]: 16.41 30.36 60.31 76.94 113.36  - 59.48

# %% [markdown]
# <br/>
#
# ---
#
# <br/>

# %% [markdown]
# # ExPI

# %%
# !python train.py --dataset expi
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/expi/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='', dataset='expi', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/MTTPF/logs/expi/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loaded Train ExPI, number of examples: 28275
# Loaded ExPI, number of examples: 432
# #Param: 5882454 5882454
# EPOCH 1 | loss train: 0.485, loss valid: 0.194 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 37.58 54.26 85.30 96.40 116.67  - 78.04
# EPOCH 2 | loss train: 0.222, loss valid: 0.172 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 26.18 44.76 77.15 88.42 109.60  - 69.22
# EPOCH 3 | loss train: 0.184, loss valid: 0.157 | lr: 0.00100
# Test s 240ms 500ms 640ms 900ms]: 20.60 39.85 71.12 83.46 105.58  - 64.12
# ...

# %%
# !python test.py --dataset expi --ckp ./logs/expi/best_epoch.pt
# Out:
# Logging into dir: /home/fipulab/notebooks/romeo/GCN-Transformer/logs/expi/
# Config: Namespace(J=13, N=2, ablation_exclude=[], amass_dataset_path='./data/amass/', batch_size=256, ckp='./logs/expi/best_epoch.pt', dataset='expi', device='cuda', finetune=False, input_len=16, log_dir='/home/fipulab/notebooks/romeo/GCN-Transformer/logs/expi/', lr=0.001, num_epoch=512, output_len=14, somof_dataset_path='./data/somof_data_3dpw/', threedpw_dataset_path='./data/3dpw/')
# Loaded Train ExPI, number of examples: 28275
# Loaded ExPI, number of examples: 432
# #Param: 5882454 5882454
# Loading model from: ./logs/expi/best_epoch.pt
# Test VIM s 240ms 500ms 640ms 900ms]: 8.32 20.84 44.56 54.81 74.66  - 40.64
# Test MPJPE s 240ms 500ms 640ms 900ms]: 13.37 27.63 57.27 71.25 97.71  - 53.45
